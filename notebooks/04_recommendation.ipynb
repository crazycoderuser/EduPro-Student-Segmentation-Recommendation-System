# %% [markdown]
# # EduPro Recommendation Engine
# Interactive notebook demonstrating EduPro ML system steps.

# %%
import sys
sys.path.append("../src")
from recommender import get_recommendations, evaluate_recommendations
print(get_recommendations("U0001", top_n=5))
evaluate_recommendations()
