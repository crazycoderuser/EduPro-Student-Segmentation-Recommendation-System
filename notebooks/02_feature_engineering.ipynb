# %% [markdown]
# # EduPro Feature Engineering
# Interactive notebook demonstrating EduPro ML system steps.

# %%
import sys
sys.path.append("../src")
from feature_engineering import run_feature_engineering
run_feature_engineering()
